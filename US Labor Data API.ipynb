# %% [markdown]
# ## U.S Bureau of Labor Statistics
#
# This website uses an API to extract data in json format :  https://www.bls.gov/developers/
#
# Sample code provided to extract data using python: https://www.bls.gov/developers/api_python.htm#python2
#
# BLS Public Data API Signatures: https://www.bls.gov/developers/api_signature_v2.htm

# %% [markdown]
# ### Series ID Formats
#
# There are several datasets that can be extracted using the API.
# * Series ID Formats: https://www.bls.gov/help/hlpforma.htm#OEUS
#   * Local Area Unemployment Rate: https://www.bls.gov/help/hlpforma.htm#LA
#   * Inflation & Prices: Consumer Price Index - Avg price data: https://www.bls.gov/help/hlpforma.htm#AP
# * For every series mentioned - use the links to understand what data you want the series to extract (Survey Overview section)

# %% [markdown]
# ### Method 1 : Using pyPI package
#
# The new Python library for the Bureau of Labor Statistics API is still being developed, but it looks promising. In order to retrieve data, use the get_series() function, which has three arguments: a series ID (or multiple IDs), a starting year and an end year.

# %% [markdown]
# #### Series Overview:
#
# Example
#
#   **Series ID    LAUCN281070000000003**
#
#   **Positions:    Value:            Field Name**
#
#   `1-2          LA               Prefix (LA-Local Area Unemployment)`
#
#   `3            S                Seasonal Adjustment Code (S-Seasonally adjusted)`
#
#   `4-18         ST1200000000000  Area Code (Florida state)`
#
#   `19-20        03               Measure Code (03-Unemployment Rate)`

# %%
import bls
#use get_series and specify start and end year
FL_unemployment_rate = bls.get_series('LASST120000000000003', 2000, 2020)
FL_unemployment_rate.head()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"><span class="ansi-red-fg">---------------------------------------------------------------------------</span>
# <span class="ansi-red-fg">ValueError</span>                                Traceback (most recent call last)
# <span class="ansi-green-fg">&lt;command-1178510690814835&gt;</span> in <span class="ansi-cyan-fg">&lt;module&gt;</span>
# <span class="ansi-green-intense-fg ansi-bold">      1</span> <span class="ansi-green-fg">import</span> bls
# <span class="ansi-green-intense-fg ansi-bold">      2</span> <span class="ansi-red-fg">#use get_series and specify start and end year</span>
# <span class="ansi-green-fg">----&gt; 3</span><span class="ansi-red-fg"> </span>FL_unemployment_rate <span class="ansi-blue-fg">=</span> bls<span class="ansi-blue-fg">.</span>get_series<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;LASST120000000000003&#39;</span><span class="ansi-blue-fg">,</span> <span class="ansi-cyan-fg">2000</span><span class="ansi-blue-fg">,</span> <span class="ansi-cyan-fg">2020</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">      4</span> FL_unemployment_rate<span class="ansi-blue-fg">.</span>head<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/bls/api.py</span> in <span class="ansi-cyan-fg">get_series</span><span class="ansi-blue-fg">(series, startyear, endyear, key)</span>
# <span class="ansi-green-intense-fg ansi-bold">    140</span>         Series object <span class="ansi-green-fg">is</span> returned instead of a DataFrame<span class="ansi-blue-fg">.</span>
# <span class="ansi-green-intense-fg ansi-bold">    141</span>     &#34;&#34;&#34;
# <span class="ansi-green-fg">--&gt; 142</span><span class="ansi-red-fg">     </span>results <span class="ansi-blue-fg">=</span> get_json_series<span class="ansi-blue-fg">(</span>series<span class="ansi-blue-fg">,</span> startyear<span class="ansi-blue-fg">,</span> endyear<span class="ansi-blue-fg">,</span> key<span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">    143</span>     df = pd.DataFrame({
# <span class="ansi-green-intense-fg ansi-bold">    144</span>         result<span class="ansi-blue-fg">[</span><span class="ansi-blue-fg">&#34;seriesID&#34;</span><span class="ansi-blue-fg">]</span><span class="ansi-blue-fg">:</span> parse_series<span class="ansi-blue-fg">(</span>result<span class="ansi-blue-fg">)</span>
#
# <span class="ansi-green-fg">/databricks/python/lib/python3.7/site-packages/bls/api.py</span> in <span class="ansi-cyan-fg">get_json_series</span><span class="ansi-blue-fg">(series, startyear, endyear, key)</span>
# <span class="ansi-green-intense-fg ansi-bold">     71</span>
# <span class="ansi-green-intense-fg ansi-bold">     72</span>     <span class="ansi-green-fg">if</span> key <span class="ansi-green-fg">is</span> <span class="ansi-green-fg">None</span> <span class="ansi-green-fg">and</span> endyear <span class="ansi-blue-fg">-</span> startyear <span class="ansi-blue-fg">&gt;=</span> <span class="ansi-cyan-fg">10</span><span class="ansi-blue-fg">:</span>
# <span class="ansi-green-fg">---&gt; 73</span><span class="ansi-red-fg">         </span><span class="ansi-green-fg">raise</span> ValueError<span class="ansi-blue-fg">(</span><span class="ansi-blue-fg">&#39;Must use API key to retrieve more than 10 years&#39;</span><span class="ansi-blue-fg">)</span>
# <span class="ansi-green-intense-fg ansi-bold">     74</span>
# <span class="ansi-green-intense-fg ansi-bold">     75</span>     <span class="ansi-green-fg">if</span> startyear <span class="ansi-green-fg">and</span> endyear <span class="ansi-blue-fg">-</span> startyear <span class="ansi-blue-fg">&gt;=</span> <span class="ansi-cyan-fg">20</span><span class="ansi-blue-fg">:</span>
#
# <span class="ansi-red-fg">ValueError</span>: Must use API key to retrieve more than 10 years</div>

# %% [markdown]
# The result is a pandas series with the year-month and unemployment rate as two elements

# %% [markdown]
# ### Method 2: Using Requests
#
# We can locate the series we want and import it into Pandas.
# * In order to find the series name and fields, refer to the Series ID Formats page.
# * Once you know the series ID for the data we want to request, simply append the ID to the version one API URL, https://api.bls.gov/publicAPI/v1/timeseries/data/<SERIES_NAME>
# * Use the `requests` Python package to return the data in dictionary or list format

# %%
import pandas as pd
import json
import requests

url = 'https://api.bls.gov/publicAPI/v1/timeseries/data/LASST120000000000003' # CUUR0000SA0 - 2nd example using the Inflation & Prices average price series
data = requests.get(url).json()
print('Status: ' + data['status'])

print(data.keys())
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Status: REQUEST_SUCCEEDED
# dict_keys([&#39;status&#39;, &#39;responseTime&#39;, &#39;message&#39;, &#39;Results&#39;])
# </div>

# %%
data

# %%
data['Results']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: {&#39;series&#39;: [{&#39;seriesID&#39;: &#39;LASST120000000000003&#39;,
#    &#39;data&#39;: [{&#39;year&#39;: &#39;2020&#39;,
#      &#39;period&#39;: &#39;M07&#39;,
#      &#39;periodName&#39;: &#39;July&#39;,
#      &#39;latest&#39;: &#39;true&#39;,
#      &#39;value&#39;: &#39;11.3&#39;,
#      &#39;footnotes&#39;: [{&#39;code&#39;: &#39;P&#39;, &#39;text&#39;: &#39;Preliminary.&#39;}]},
#     {&#39;year&#39;: &#39;2020&#39;,
#      &#39;period&#39;: &#39;M06&#39;,
#      &#39;periodName&#39;: &#39;June&#39;,
#      &#39;value&#39;: &#39;10.3&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2020&#39;,
#      &#39;period&#39;: &#39;M05&#39;,
#      &#39;periodName&#39;: &#39;May&#39;,
#      &#39;value&#39;: &#39;13.7&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2020&#39;,
#      &#39;period&#39;: &#39;M04&#39;,
#      &#39;periodName&#39;: &#39;April&#39;,
#      &#39;value&#39;: &#39;13.8&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2020&#39;,
#      &#39;period&#39;: &#39;M03&#39;,
#      &#39;periodName&#39;: &#39;March&#39;,
#      &#39;value&#39;: &#39;4.4&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2020&#39;,
#      &#39;period&#39;: &#39;M02&#39;,
#      &#39;periodName&#39;: &#39;February&#39;,
#      &#39;value&#39;: &#39;2.8&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2020&#39;,
#      &#39;period&#39;: &#39;M01&#39;,
#      &#39;periodName&#39;: &#39;January&#39;,
#      &#39;value&#39;: &#39;2.8&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2019&#39;,
#      &#39;period&#39;: &#39;M12&#39;,
#      &#39;periodName&#39;: &#39;December&#39;,
#      &#39;value&#39;: &#39;2.9&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2019&#39;,
#      &#39;period&#39;: &#39;M11&#39;,
#      &#39;periodName&#39;: &#39;November&#39;,
#      &#39;value&#39;: &#39;2.8&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2019&#39;,
#      &#39;period&#39;: &#39;M10&#39;,
#      &#39;periodName&#39;: &#39;October&#39;,
#      &#39;value&#39;: &#39;2.9&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2019&#39;,
#      &#39;period&#39;: &#39;M09&#39;,
#      &#39;periodName&#39;: &#39;September&#39;,
#      &#39;value&#39;: &#39;2.9&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2019&#39;,
#      &#39;period&#39;: &#39;M08&#39;,
#      &#39;periodName&#39;: &#39;August&#39;,
#      &#39;value&#39;: &#39;3.0&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2019&#39;,
#      &#39;period&#39;: &#39;M07&#39;,
#      &#39;periodName&#39;: &#39;July&#39;,
#      &#39;value&#39;: &#39;3.1&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2019&#39;,
#      &#39;period&#39;: &#39;M06&#39;,
#      &#39;periodName&#39;: &#39;June&#39;,
#      &#39;value&#39;: &#39;3.2&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2019&#39;,
#      &#39;period&#39;: &#39;M05&#39;,
#      &#39;periodName&#39;: &#39;May&#39;,
#      &#39;value&#39;: &#39;3.2&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2019&#39;,
#      &#39;period&#39;: &#39;M04&#39;,
#      &#39;periodName&#39;: &#39;April&#39;,
#      &#39;value&#39;: &#39;3.3&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2019&#39;,
#      &#39;period&#39;: &#39;M03&#39;,
#      &#39;periodName&#39;: &#39;March&#39;,
#      &#39;value&#39;: &#39;3.4&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2019&#39;,
#      &#39;period&#39;: &#39;M02&#39;,
#      &#39;periodName&#39;: &#39;February&#39;,
#      &#39;value&#39;: &#39;3.4&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2019&#39;,
#      &#39;period&#39;: &#39;M01&#39;,
#      &#39;periodName&#39;: &#39;January&#39;,
#      &#39;value&#39;: &#39;3.4&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2018&#39;,
#      &#39;period&#39;: &#39;M12&#39;,
#      &#39;periodName&#39;: &#39;December&#39;,
#      &#39;value&#39;: &#39;3.4&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2018&#39;,
#      &#39;period&#39;: &#39;M11&#39;,
#      &#39;periodName&#39;: &#39;November&#39;,
#      &#39;value&#39;: &#39;3.4&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2018&#39;,
#      &#39;period&#39;: &#39;M10&#39;,
#      &#39;periodName&#39;: &#39;October&#39;,
#      &#39;value&#39;: &#39;3.4&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2018&#39;,
#      &#39;period&#39;: &#39;M09&#39;,
#      &#39;periodName&#39;: &#39;September&#39;,
#      &#39;value&#39;: &#39;3.4&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2018&#39;,
#      &#39;period&#39;: &#39;M08&#39;,
#      &#39;periodName&#39;: &#39;August&#39;,
#      &#39;value&#39;: &#39;3.4&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2018&#39;,
#      &#39;period&#39;: &#39;M07&#39;,
#      &#39;periodName&#39;: &#39;July&#39;,
#      &#39;value&#39;: &#39;3.5&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2018&#39;,
#      &#39;period&#39;: &#39;M06&#39;,
#      &#39;periodName&#39;: &#39;June&#39;,
#      &#39;value&#39;: &#39;3.6&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2018&#39;,
#      &#39;period&#39;: &#39;M05&#39;,
#      &#39;periodName&#39;: &#39;May&#39;,
#      &#39;value&#39;: &#39;3.7&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2018&#39;,
#      &#39;period&#39;: &#39;M04&#39;,
#      &#39;periodName&#39;: &#39;April&#39;,
#      &#39;value&#39;: &#39;3.7&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2018&#39;,
#      &#39;period&#39;: &#39;M03&#39;,
#      &#39;periodName&#39;: &#39;March&#39;,
#      &#39;value&#39;: &#39;3.8&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2018&#39;,
#      &#39;period&#39;: &#39;M02&#39;,
#      &#39;periodName&#39;: &#39;February&#39;,
#      &#39;value&#39;: &#39;3.9&#39;,
#      &#39;footnotes&#39;: [{}]},
#     {&#39;year&#39;: &#39;2018&#39;,
#      &#39;period&#39;: &#39;M01&#39;,
#      &#39;periodName&#39;: &#39;January&#39;,
#      &#39;value&#39;: &#39;3.9&#39;,
#      &#39;footnotes&#39;: [{}]}]}]}</div>

# %%
#Look into the keys under Results
data['Results'].keys()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[13]: dict_keys([&#39;series&#39;])</div>

# %%
#Look into series ID under series
for i in data['Results']['series']:
  print(i['seriesID'])
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">LASST120000000000003
# </div>

# %%
data['Results']['series']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[15]: [{&#39;seriesID&#39;: &#39;LASST120000000000003&#39;,
#   &#39;data&#39;: [{&#39;year&#39;: &#39;2020&#39;,
#     &#39;period&#39;: &#39;M07&#39;,
#     &#39;periodName&#39;: &#39;July&#39;,
#     &#39;latest&#39;: &#39;true&#39;,
#     &#39;value&#39;: &#39;11.3&#39;,
#     &#39;footnotes&#39;: [{&#39;code&#39;: &#39;P&#39;, &#39;text&#39;: &#39;Preliminary.&#39;}]},
#    {&#39;year&#39;: &#39;2020&#39;,
#     &#39;period&#39;: &#39;M06&#39;,
#     &#39;periodName&#39;: &#39;June&#39;,
#     &#39;value&#39;: &#39;10.3&#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2020&#39;,
#     &#39;period&#39;: &#39;
#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2018&#39;,
#     &#39;period&#39;: &#39;M01&#39;,
#     &#39;periodName&#39;: &#39;January&#39;,
#     &#39;value&#39;: &#39;3.9&#39;,
#     &#39;footnotes&#39;: [{}]}]}]</div>

# %% [markdown]
# We are interested in extracting the `data` element of the json so we convert it into pandas table

# %%
df=pd.json_normalize(data['Results']['series'],'data')
df.head(10)
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>year</th>
#       <th>period</th>
#       <th>periodName</th>
#       <th>latest</th>
#       <th>value</th>
#       <th>footnotes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020</td>
#       <td>M07</td>
#       <td>July</td>
#       <td>true</td>
#       <td>11.3</td>
#       <td>[{'code': 'P', 'text': 'Preliminary.'}]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2020</td>
#       <td>M06</td>
#       <td>June</td>
#       <td>NaN</td>
#       <td>10.3</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2020</td>
#       <td>M05</td>
#       <td>May</td>
#       <td>NaN</td>
#       <td>13.7</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2020</td>
#       <td>M04</td>
#       <td>April</td>
#       <td>NaN</td>
#       <td>13.8</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2020</td>
#       <td>M03</td>
#       <td>March</td>
#       <td>NaN</td>
#       <td>4.4</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>5</th>
#       <td>2020</td>
#       <td>M02</td>
#       <td>February</td>
#       <td>NaN</td>
#       <td>2.8</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>6</th>
#       <td>2020</td>
#       <td>M01</td>
#       <td>January</td>
#       <td>NaN</td>
#       <td>2.8</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>7</th>
#       <td>2019</td>
#       <td>M12</td>
#       <td>December</td>
#       <td>NaN</td>
#       <td>2.9</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>8</th>
#       <td>2019</td>
#       <td>M11</td>
#       <td>November</td>
#       <td>NaN</td>
#       <td>2.8</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>9</th>
#       <td>2019</td>
#       <td>M10</td>
#       <td>October</td>
#       <td>NaN</td>
#       <td>2.9</td>
#       <td>[{}]</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
#Drop the unwanted columns
df = df.drop(['latest', 'footnotes'],axis=1)
#Rename column
df = df.rename(columns={"value":"unemploymentRate"})
df.head()
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>year</th>
#       <th>period</th>
#       <th>periodName</th>
#       <th>unemploymentRate</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2020</td>
#       <td>M07</td>
#       <td>July</td>
#       <td>11.3</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2020</td>
#       <td>M06</td>
#       <td>June</td>
#       <td>10.3</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2020</td>
#       <td>M05</td>
#       <td>May</td>
#       <td>13.7</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2020</td>
#       <td>M04</td>
#       <td>April</td>
#       <td>13.8</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2020</td>
#       <td>M03</td>
#       <td>March</td>
#       <td>4.4</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %% [markdown]
# #### Method 3
#
# This code writes the data to text files, named according to the series they're derived from. You can simply replace the values for series ID and years in the sample code if you like, but you'll eventually find that limits your options a bit.

# %%
import requests
import json
import prettytable
import pandas as pd
import numpy as np

headers = {'Content-type': 'application/json'}
data = json.dumps({"seriesid": ['CUUR0000SA0','SUUR0000SA0'],"startyear":"2000", "endyear":"2020"})
p = requests.post('https://api.bls.gov/publicAPI/v2/timeseries/data/', data=data, headers=headers)
json_data = json.loads(p.text)
for series in json_data['Results']['series']:
    x=prettytable.PrettyTable(["series id","year","period","value","footnotes"])
    seriesId = series['seriesID']
    for item in series['data']:
        year = item['year']
        period = item['period']
        value = item['value']
        footnotes=""
        for footnote in item['footnotes']:
            if footnote:
                footnotes = footnotes + footnote['text'] + ','
        if 'M01' <= period <= 'M12':
            x.add_row([seriesId,year,period,value,footnotes[0:-1]])
    output = open(seriesId + '.txt','w')
    output.write (x.get_string())
    output.close()
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout"></div>

# %%
json_data['Results']['series']
# Out:
# <style scoped>
#   .ansiout {
#     display: block;
#     unicode-bidi: embed;
#     white-space: pre-wrap;
#     word-wrap: break-word;
#     word-break: break-all;
#     font-family: "Source Code Pro", "Menlo", monospace;;
#     font-size: 13px;
#     color: #555;
#     margin-left: 4px;
#     line-height: 19px;
#   }
# </style>
# <div class="ansiout">Out[12]: [{&#39;seriesID&#39;: &#39;CUUR0000SA0&#39;,
#   &#39;data&#39;: [{&#39;year&#39;: &#39;2009&#39;,
#     &#39;period&#39;: &#39;M12&#39;,
#     &#39;periodName&#39;: &#39;December&#39;,
#     &#39;value&#39;: &#39;215.949&#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2009&#39;,
#     &#39;period&#39;: &#39;M11&#39;,
#     &#39;periodName&#39;: &#39;November&#39;,
#     &#39;value&#39;: &#39;216.330&#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2009&#39;,
#     &#39;period&#39;: &#39;M10&#39;,
#     &#39;periodName&#39;: &#39;October&#39;,
#     &#39;value&#39;: &#39;216.177&#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2009&#39;,
#     &#39;period&#39;: &#39;M09&#39;,
#     &#39;periodName&#39;: &#39;September&#39;,
#     &#39;value&#39;: &#39;215.969&#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2009&#39;,
#     &#39;period&#39;: &#39;M08&#39;,
#     &#39;periodName&#39;: &#39;August&#39;,
#     &#39;value&#39;: &#39;215.834&#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2009&#39;,
#     &#39;period&#39;: &#39;M07&#39;,
#     &#39;periodName&#39;: &#39;July&#39;,
#     &#39;value&#39;: &#39;215.351&#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2009&#39;,
#     &#39;period&#39;: &#39;
#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2007&#39;,
#     &#39;period&#39;: &#39;M04&#39;,
#     &#39;periodName&#39;: &#39;April&#39;,
#     &#39;value&#39;: &#39;206.686&#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2007&#39;,
#     &#39;period&#39;: &#39;M03&#39;,
#     &#39;periodName&#39;: &#39;March&#39;,
#     &#39;value&#39;: &#39;205.352&#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2007&#39;,
#     &#39;period&#39;: &#39;M02&#39;,
#     &#39;periodName&#39;: &#39;February&#39;,
#     &#39;value&#39;: &#39;203.499&#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2007&#39;,
#     &#39;period&#39;: &#39;M01&#39;,
#     &#39;periodName&#39;: &#39;January&#39;,
#     &#39;value&#39;: &#39;202.416&#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2006&#39;,
#     &#39;period&#39;: &#39;M12&#39;,
#     &#39;periodName&#39;: &#39;December&#39;,
#     &#39;value&#39;: &#39;201.8&#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2006&#39;,
#     &#39;period&#39;: &#39;M11&#39;,
#     &#39;periodName&#39;: &#39;November&#39;,
#     &#39;value&#39;: &#39;201.5&#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2006&#39;,
#     &#39;period&#39;: &#39;M10&#39;,
#     &#39;periodName&#39;: &#39;October&#39;,
#     &#39;value&#39;: &#39;201.8&#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2006&#39;,
#     &#39;period&#39;: &#39;M09&#39;,
#     &#39;periodName&#39;: &#39;September&#39;,
#     &#39;value&#39;: &#39;202.9&#39;,
#     &#39;footnotes&#39;: [{}]},
#    {&#39;year&#39;: &#39;2006&#39;,

# %%
multi_df=pd.json_normalize(json_data['Results']['series'])
multi_df
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>seriesID</th>
#       <th>data</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CUUR0000SA0</td>
#       <td>[{'year': '2009', 'period': 'M12', 'periodName...</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>SUUR0000SA0</td>
#       <td>[{'year': '2009', 'period': 'M12', 'periodName...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
inflation_and_prices = multi_df[multi_df['seriesID']=="CUUR0000SA0"]
inflation_and_prices
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>seriesID</th>
#       <th>data</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>CUUR0000SA0</td>
#       <td>[{'year': '2009', 'period': 'M12', 'periodName...</td>
#     </tr>
#   </tbody>
# </table>
# </div>

# %%
inflation_series=pd.json_normalize(inflation_and_prices.explode('data')['data'])
inflation_series
# Out:
# <div>
# <style scoped>
#     .dataframe tbody tr th:only-of-type {
#         vertical-align: middle;
#     }
#
#     .dataframe tbody tr th {
#         vertical-align: top;
#     }
#
#     .dataframe thead th {
#         text-align: right;
#     }
# </style>
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>year</th>
#       <th>period</th>
#       <th>periodName</th>
#       <th>value</th>
#       <th>footnotes</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th>0</th>
#       <td>2009</td>
#       <td>M12</td>
#       <td>December</td>
#       <td>215.949</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>1</th>
#       <td>2009</td>
#       <td>M11</td>
#       <td>November</td>
#       <td>216.330</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>2</th>
#       <td>2009</td>
#       <td>M10</td>
#       <td>October</td>
#       <td>216.177</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>3</th>
#       <td>2009</td>
#       <td>M09</td>
#       <td>September</td>
#       <td>215.969</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>4</th>
#       <td>2009</td>
#       <td>M08</td>
#       <td>August</td>
#       <td>215.834</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>...</th>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#       <td>...</td>
#     </tr>
#     <tr>
#       <th>115</th>
#       <td>2000</td>
#       <td>M05</td>
#       <td>May</td>
#       <td>171.5</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>116</th>
#       <td>2000</td>
#       <td>M04</td>
#       <td>April</td>
#       <td>171.3</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>117</th>
#       <td>2000</td>
#       <td>M03</td>
#       <td>March</td>
#       <td>171.2</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>118</th>
#       <td>2000</td>
#       <td>M02</td>
#       <td>February</td>
#       <td>169.8</td>
#       <td>[{}]</td>
#     </tr>
#     <tr>
#       <th>119</th>
#       <td>2000</td>
#       <td>M01</td>
#       <td>January</td>
#       <td>168.8</td>
#       <td>[{}]</td>
#     </tr>
#   </tbody>
# </table>
# <p>120 rows × 5 columns</p>
# </div>

# %% [markdown]
# **References**
#
# * Series Information : https://www.bls.gov/help/hlpforma.htm#LA
# * Ref article: http://danstrong.tech/blog/BLS-API/
